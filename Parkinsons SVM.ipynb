# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Datasets/parkinsons.data")

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer    ...     \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374    ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134    ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233    ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492    ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425    ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
df = df.drop('name', axis = 1)

# %%
df.head(2)
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)    ...     \
# 0   0.00370   0.00554     0.01109       0.04374             0.426    ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626    ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
#
# [2 rows x 23 columns]

# %%
y = df[['status']]

# %%
X = df.drop('status', axis = 1)

# %%
y.head(2)
# Out:
#    status
# 0       1
# 1       1

# %%
X.head(2)
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)    ...     \
# 0   0.00370   0.00554     0.01109       0.04374             0.426    ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626    ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# 0   0.02971      0.06545  0.02211  21.033  0.414783  0.815285 -4.813031
# 1   0.04368      0.09403  0.01929  19.085  0.458359  0.819521 -4.075192
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
#
# [2 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=7)

# %%
from sklearn import preprocessing

# %%
from sklearn.svm  import SVC
# svc = SVC()

# %%
#svc.fit(X_train,y_train)

# %%
#svc.score(X_test,y_test)

# %%
pre = ['Normalizer', 'MaxAbsScaler', 'MinMaxScaler', 'KernelCenterer', 'StandardScaler']
prepro = preprocessing.StandardScaler()
prepro.fit(X_train)
X_train = prepro.transform(X_train)
X_test = prepro.transform(X_test)

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 14,svd_solver = 'randomized')
# pca.fit(X_train)
# X_train = pca.transform(X_train)
# X_test = pca.transform(X_test)
from sklearn import manifold
iso = manifold.Isomap(n_neighbors = 5, n_components = 4)
iso.fit(X_train)
X_train = iso.transform(X_train)
X_test = iso.transform(X_test)

# %%
scores = []
gammas = []
Cs = []
for C in np.arange(0.05, 2, 0.05 ):
    for gamma in np.arange(0.001, 0.1, 0.001 ):
        svc = SVC(C = C, gamma = gamma, kernel = 'rbf')
        svc.fit(X_train,y_train)
        score = svc.score(X_test,y_test)
        scores.append(score)
        gammas.append(gamma)
        Cs.append(Cs)
# Out:
# C:\Users\SUYASH\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
percentile_list = pd.DataFrame(
    {'lst1Title': scores,
     'lst2Title': gammas,
     'lst3Title': Cs
    })

# %%
max(scores)
# Out:
# 0.9491525423728814
